# %% [markdown]
#                                                                             Suyash Tambe
#                                                                             22070126117
#                                                                             AIML B2
#                                                                             DPL - Task 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Read the csv file

# %%
df = pd.read_csv(r'C:\Users\Suyash Tambe\Desktop\DPL VS CODE\ch2\ch2\superConFeatures.csv')
df
# Out:
#                           Material ()  NumberOfElements ()  \
# 0      Hg0.66Pb0.34Ba2Ca1.98Cu2.9O8.4                    6
# 1               Tl0.8Hg0.2Ba2Ca2Cu3O9                    6
# 2           Bi1.6Pb0.4Sb0.1Sr2Ca2Cu2O                    7
# 3           Bi1.8Pb0.2Sb0.1Sr2Ca2Cu2O                    7
# 4      Hg0.75Ba2.07Ca2.07Cu3.11O8.208                    5
# ...                               ...                  ...
# 15537                             Pt1                    1
# 15538          Gd0.9Pr0.95Ce0.15Cu1O4                    5
# 15539      La1.92Sr0.08Cu0.99Ni0.01O4                    5
# 15540                  Au0.978In0.022                    2
# 15541                             Rh1                    1
#
#        MeanAtomicMass (AMU)  WtdMeanAtomicMass (AMU)  GmeanAtomicMass (AMU)  \
# 0                110.790067                53.779128              78.419756
# 1                110.320617                52.533367              78.241067
# ...

# %%
df.head()
# Out:
#                       Material ()  NumberOfElements ()  MeanAtomicMass (AMU)  \
# 0  Hg0.66Pb0.34Ba2Ca1.98Cu2.9O8.4                    6            110.790067
# 1           Tl0.8Hg0.2Ba2Ca2Cu3O9                    6            110.320617
# 2       Bi1.6Pb0.4Sb0.1Sr2Ca2Cu2O                    7            106.454829
# 3       Bi1.8Pb0.2Sb0.1Sr2Ca2Cu2O                    7            106.454829
# 4  Hg0.75Ba2.07Ca2.07Cu3.11O8.208                    5             91.508080
#
#    WtdMeanAtomicMass (AMU)  GmeanAtomicMass (AMU)  WtdGmeanAtomicMass (AMU)  \
# 0                53.779128              78.419756                 34.814175
# 1                52.533367              78.241067                 34.005520
# 2                90.979345              78.774541                 69.263213
# 3                91.018475              78.774541                 69.276239
# 4                52.234821              64.570275                 34.675999
#
# ...

# %% [markdown]
# 2. Remove the missing values.

# %%
df.isnull().sum()
# Out:
# Material ()                0
# NumberOfElements ()        0
# MeanAtomicMass (AMU)       0
# WtdMeanAtomicMass (AMU)    0
# GmeanAtomicMass (AMU)      0
#                           ..
# RangeValence ()            0
# WtdRangeValence ()         0
# StdValence ()              0
# WtdStdValence ()           0
# CriticalTemp (K)           0
# Length: 83, dtype: int64

# %%
df.dropna()
# Out:
#                           Material ()  NumberOfElements ()  \
# 0      Hg0.66Pb0.34Ba2Ca1.98Cu2.9O8.4                    6
# 2           Bi1.6Pb0.4Sb0.1Sr2Ca2Cu2O                    7
# 3           Bi1.8Pb0.2Sb0.1Sr2Ca2Cu2O                    7
# 4      Hg0.75Ba2.07Ca2.07Cu3.11O8.208                    5
# 5      Hg0.75Ba2.07Ca2.07Cu3.11O8.187                    5
# ...                               ...                  ...
# 15537                             Pt1                    1
# 15538          Gd0.9Pr0.95Ce0.15Cu1O4                    5
# 15539      La1.92Sr0.08Cu0.99Ni0.01O4                    5
# 15540                  Au0.978In0.022                    2
# 15541                             Rh1                    1
#
#        MeanAtomicMass (AMU)  WtdMeanAtomicMass (AMU)  GmeanAtomicMass (AMU)  \
# 0                110.790067                53.779128              78.419756
# 2                106.454829                90.979345              78.774541
# ...

# %% [markdown]
# 3. Normalize all the values

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a Min-Max scaler
scaler = MinMaxScaler()

df[['MeanAtomicMass (AMU)', 'WtdMeanAtomicMass (AMU)','GmeanAtomicMass (AMU)','WtdGmeanAtomicMass (AMU)','EntropyAtomicMass ()','WtdEntropyAtomicMass ()','RangeAtomicMass (AMU)',
    'WtdRangeAtomicMass (AMU)','StdAtomicMass (AMU)','WtdStdAtomicMass (AMU)','MeanFie (kJ/mol)','WtdMeanFie (kJ/mol)',	'GmeanFie (kJ/mol)',
    'WtdGmeanFie (kJ/mol)',	'EntropyFie ()',	'WtdEntropyFie ()',	'RangeFie (kJ/mol)',	'WtdRangeFie (kJ/mol)',	'StdFie (kJ/mol)'	,'WtdStdFie (kJ/mol)',
    'MeanAtomicRadius (pm)','WtdMeanAtomicRadius (pm)',	'GmeanAtomicRadius (pm)',	'WtdGmeanAtomicRadius (pm)',	'EntropyAtomicRadius ()',	'WtdEntropyAtomicRadius ()',	'RangeAtomicRadius (pm)',	'WtdRangeAtomicRadius (pm)',	
    'StdAtomicRadius (pm)',	'WtdStdAtomicRadius (pm)',	'MeanDensity (kg/m^3)',	'WtdMeanDensity (kg/m^3)',	
    'GmeanDensity (kg/m^3)','WtdGmeanDensity (kg/m^3)',	'EntropyDensity ()',	'WtdEntropyDensity ()',	'RangeDensity (kg/m^3)',	'WtdRangeDensity (kg/m^3)',	'StdDensity (kg/m^3)',	'WtdStdDensity (kg/m^3)',	'MeanElectronAffinity (kJ/mol)',	
    'WtdMeanElectronAffinity (kJ/mol)'	,'GmeanElectronAffinity (kJ/mol)',	'WtdGmeanElectronAffinity (kJ/mol)',	'EntropyElectronAffinity ()',	'WtdEntropyElectronAffinity ()',	'RangeElectronAffinity (kJ/mol)',
    'WtdRangeElectronAffinity (kJ/mol)','StdElectronAffinity (kJ/mol)',	'WtdStdElectronAffinity (kJ/mol)',	'MeanFusionHeat (kJ/mol)',	'WtdMeanFusionHeat (kJ/mol)',	'GmeanFusionHeat (kJ/mol)',	'WtdGmeanFusionHeat (kJ/mol)',	
    'EntropyFusionHeat ()',	'WtdEntropyFusionHeat ()',	'RangeFusionHeat (kJ/mol)',	'WtdRangeFusionHeat (kJ/mol)',	'StdFusionHeat (kJ/mol)',	'WtdStdFusionHeat (kJ/mol)',	'MeanThermalConductivity (W/(m.K))',
    'WtdMeanThermalConductivity (W/(m.K))',	'GmeanThermalConductivity (W/(m.K))',	'WtdGmeanThermalConductivity (W/(m.K))',	'EntropyThermalConductivity ()',
    'WtdEntropyThermalConductivity ()',	'RangeThermalConductivity (W/(m.K))',	'WtdRangeThermalConductivity (W/(m.K))',	'StdThermalConductivity (W/(m.K))',	'WtdStdThermalConductivity (W/(m.K))',	'MeanValence ()',	'WtdMeanValence ()',	'GmeanValence ()',	'WtdGmeanValence ()',
    'EntropyValence ()',	'WtdEntropyValence ()',	'RangeValence ()',	
    'WtdRangeValence ()',	'StdValence ()',	'WtdStdValence ()',	'CriticalTemp (K)']] = scaler.fit_transform(df[['MeanAtomicMass (AMU)', 'WtdMeanAtomicMass (AMU)','GmeanAtomicMass (AMU)','WtdGmeanAtomicMass (AMU)','EntropyAtomicMass ()','WtdEntropyAtomicMass ()','RangeAtomicMass (AMU)',
    'WtdRangeAtomicMass (AMU)','StdAtomicMass (AMU)','WtdStdAtomicMass (AMU)','MeanFie (kJ/mol)','WtdMeanFie (kJ/mol)',	'GmeanFie (kJ/mol)',
    'WtdGmeanFie (kJ/mol)',	'EntropyFie ()',	'WtdEntropyFie ()',	'RangeFie (kJ/mol)',	'WtdRangeFie (kJ/mol)',	'StdFie (kJ/mol)'	,'WtdStdFie (kJ/mol)',
    'MeanAtomicRadius (pm)','WtdMeanAtomicRadius (pm)',	'GmeanAtomicRadius (pm)',	'WtdGmeanAtomicRadius (pm)',	'EntropyAtomicRadius ()',	'WtdEntropyAtomicRadius ()',	'RangeAtomicRadius (pm)',	'WtdRangeAtomicRadius (pm)',	
    'StdAtomicRadius (pm)',	'WtdStdAtomicRadius (pm)',	'MeanDensity (kg/m^3)',	'WtdMeanDensity (kg/m^3)',	
    'GmeanDensity (kg/m^3)','WtdGmeanDensity (kg/m^3)',	'EntropyDensity ()',	'WtdEntropyDensity ()',	'RangeDensity (kg/m^3)',	'WtdRangeDensity (kg/m^3)',	'StdDensity (kg/m^3)',	'WtdStdDensity (kg/m^3)',	'MeanElectronAffinity (kJ/mol)',	
    'WtdMeanElectronAffinity (kJ/mol)'	,'GmeanElectronAffinity (kJ/mol)',	'WtdGmeanElectronAffinity (kJ/mol)',	'EntropyElectronAffinity ()',	'WtdEntropyElectronAffinity ()',	'RangeElectronAffinity (kJ/mol)',
    'WtdRangeElectronAffinity (kJ/mol)','StdElectronAffinity (kJ/mol)',	'WtdStdElectronAffinity (kJ/mol)',	'MeanFusionHeat (kJ/mol)',	'WtdMeanFusionHeat (kJ/mol)',	'GmeanFusionHeat (kJ/mol)',	'WtdGmeanFusionHeat (kJ/mol)',	
    'EntropyFusionHeat ()',	'WtdEntropyFusionHeat ()',	'RangeFusionHeat (kJ/mol)',	'WtdRangeFusionHeat (kJ/mol)',	'StdFusionHeat (kJ/mol)',	'WtdStdFusionHeat (kJ/mol)',	'MeanThermalConductivity (W/(m.K))',
    'WtdMeanThermalConductivity (W/(m.K))',	'GmeanThermalConductivity (W/(m.K))',	'WtdGmeanThermalConductivity (W/(m.K))',	'EntropyThermalConductivity ()',
    'WtdEntropyThermalConductivity ()',	'RangeThermalConductivity (W/(m.K))',	'WtdRangeThermalConductivity (W/(m.K))',	'StdThermalConductivity (W/(m.K))',	'WtdStdThermalConductivity (W/(m.K))',	'MeanValence ()',	'WtdMeanValence ()',	'GmeanValence ()',	'WtdGmeanValence ()',
    'EntropyValence ()',	'WtdEntropyValence ()',	'RangeValence ()',	
    'WtdRangeValence ()',	'StdValence ()',	'WtdStdValence ()',	'CriticalTemp (K)']])
# Out:
# C:\Users\Suyash Tambe\AppData\Local\Temp\ipykernel_3912\4091805256.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['MeanAtomicMass (AMU)', 'WtdMeanAtomicMass (AMU)','GmeanAtomicMass (AMU)','WtdGmeanAtomicMass (AMU)','EntropyAtomicMass ()','WtdEntropyAtomicMass ()','RangeAtomicMass (AMU)',

# %%
df
# Out:
#                           Material ()  NumberOfElements ()  \
# 0      Hg0.66Pb0.34Ba2Ca1.98Cu2.9O8.4                    6
# 2           Bi1.6Pb0.4Sb0.1Sr2Ca2Cu2O                    7
# 3           Bi1.8Pb0.2Sb0.1Sr2Ca2Cu2O                    7
# 4      Hg0.75Ba2.07Ca2.07Cu3.11O8.208                    5
# 5      Hg0.75Ba2.07Ca2.07Cu3.11O8.187                    5
# ...                               ...                  ...
# 15537                             Pt1                    1
# 15538          Gd0.9Pr0.95Ce0.15Cu1O4                    5
# 15539      La1.92Sr0.08Cu0.99Ni0.01O4                    5
# 15540                  Au0.978In0.022                    2
# 15541                             Rh1                    1
#
#        MeanAtomicMass (AMU)  WtdMeanAtomicMass (AMU)  GmeanAtomicMass (AMU)  \
# 0                  0.514004                 0.233789               0.358928
# 2                  0.492547                 0.417443               0.360670
# ...

# %% [markdown]
# 4. Represent each entity in graph

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
plt.scatter(df['MeanAtomicMass (AMU)'], df['WtdMeanAtomicMass (AMU)'], label='Data Points', c='blue', marker='o')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
plt.scatter(df['RangeValence ()'], df['WtdRangeValence ()'], label='Data Points', c='orange', marker='o')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot')
plt.legend()
plt.show()
